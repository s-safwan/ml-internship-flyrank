# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/s-safwan/ml-internship-flyrank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **Lane 2**: Refresh / Content Opportunity Scoring.
#
# **Why**: I selected this lane because it provides a direct, actionable business output. Marketing and SEO teams have limited editorial capacity, and they cannot review every page manually. By building a scored review queue, this project will help allocate human effort to the pages where a content refresh, expansion, or metadata update will yield the highest ROI.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **The Decision**: This work improves the prioritization of the content review queue. It decides which existing pages, out of thousands, require immediate editorial attention.
#
# **The Action**: The SEO and marketing teams will act on this ranked list. They will manually review the flagged pages and apply necessary updates, such as rewriting metadata, expanding thin content, or updating stale information.
#
# **Cost of a Wrong Call**: If the model incorrectly flags a perfectly healthy page, the primary cost is wasted editorial capacity. A secondary risk is "fixing what isn't broken," which could accidentally disrupt the page's current rankings and hurt its CTR.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd
url = "https://raw.githubusercontent.com/s-safwan/ml-internship-flyrank/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

total_pages = len(df)

declining_pages = len(df[df["trend_direction"] == "down"])

print(f"Total pages in dataset: {total_pages}")
print(f"Pages dropping in traffic: {declining_pages}")

percentage = (declining_pages / total_pages) * 100
print(f"Percentage of pages dying: {percentage:.1f}%")
# Out:
# Total pages in dataset: 30000
# Pages dropping in traffic: 16262
# Percentage of pages dying: 54.2%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **What I can claim:**
# I can claim that this model provides a directional, decision-support score. It uses observed historical signals to rank pages so the team knows which ones to review first.
# **What I cannot claim:**
# I cannot claim causality. I cannot guarantee that editing a page will cause its traffic to recover, because this is observational data, not a controlled experiment. I am also not claiming to "predict Google's algorithm".

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
